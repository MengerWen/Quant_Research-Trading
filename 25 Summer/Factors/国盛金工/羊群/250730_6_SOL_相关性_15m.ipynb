# %%
import sys
sys.path.append('/public/src')
from factor_evaluation_server import FactorEvaluation,DataService # type: ignore
import numpy as np
import pandas as pd

# %%
ds=DataService()
df=ds['SOLUSDT_15m_2020_2025']['2021-10-01':]

# %%
evaluator=FactorEvaluation(df=df,future_return_periods=10)

# %% [markdown]
# # 定义因子！

# %%
def factor(df):
    """
    计算羊群效应相关性因子：
    1. 识别趋势资金分钟（成交量 > 过去5日分钟成交量90%分位数）
    2. 对每个趋势资金分钟，找到随后5分钟内最大成交量的跟随分钟
    3. 按日计算趋势资金分钟成交量与跟随成交量的相关系数
    4. 取20日移动平均作为最终因子值
    """
    # 复制数据避免警告
    df = df.copy()
    
    # 计算过去5日（96*5分钟）成交量90%分位数
    # 使用min_periods=1确保有足够数据，closed='left'避免未来数据
    df['vol_q90'] = df['volume'].rolling(window=96*5, min_periods=1, closed='left').quantile(0.90)
    
    # 识别趋势资金分钟（当前分钟成交量突破90%分位数）
    df['is_trend'] = df['volume'] > df['vol_q90']
    
    # 提取日期列用于分组
    df['date'] = df.index.date
    
    # 准备存储结果
    daily_corr = []
    
    # 按天处理数据
    for date, group in df.groupby('date'):
        # 获取当天的趋势资金分钟
        trend_minutes = group[group['is_trend']]
        if len(trend_minutes) < 2:  # 需要至少2个点计算相关系数
            daily_corr.append(np.nan)
            continue
            
        trend_volumes = []
        follow_volumes = []
        
        # 处理每个趋势资金分钟
        for idx, row in trend_minutes.iterrows():
            # 找到当前分钟在原始df中的位置
            pos = df.index.get_loc(idx)
            # 获取随后5分钟数据（不包括当前分钟）
            future_window = df.iloc[pos+1:pos+6]
            
            if not future_window.empty:
                # 找到跟随分钟（随后5分钟内成交量最大的分钟）
                follow_minute = future_window['volume'].idxmax()
                follow_vol = df.at[follow_minute, 'volume']
                
                trend_volumes.append(row['volume'])
                follow_volumes.append(follow_vol)
        
        # 计算当日相关系数
        if len(trend_volumes) >= 2:
            corr = np.corrcoef(trend_volumes, follow_volumes)[0, 1]
            daily_corr.append(corr)
        else:
            daily_corr.append(np.nan)
    
    # 创建日级因子DataFrame
    daily_df = pd.DataFrame({
        'date': df['date'].unique(),
        'daily_corr': daily_corr
    })
    
    # 计算20日移动平均
    daily_df['factor'] = daily_df['daily_corr'].rolling(window=20, min_periods=1).mean()
    
    # 将日级因子映射回分钟数据
    date_to_factor = daily_df.set_index('date')['factor']
    df['factor'] = df['date'].map(date_to_factor)
    
    return df['factor']

# %% [markdown]
# # 测试因子表现

# %%
evaluator.set_factor(
    factor_func=lambda df: factor(df),
    factor_name='factor'
)

result=evaluator.run_full_evaluation(run_stationarity_test=True)
# Out:
# 📊 单币种 (single) 详细评估结果:
# --------------------------------------------------
# 📈 平稳性检验 (ADF):
#    p_value: 0.000000
#    是否平稳: 是
# 🔗 相关性分析:
#    IC (Pearson): 0.010508
#    Rank_IC (Spearman): 0.012343
# 📊 信息比率:
#    IR: 0.486221
#    有效分组数: 10
# 📊 因子分布:
# 📋 数据概况:
#    数据长度: 131038
#    因子列: factor
#    收益率列: future_return
#    未来收益周期: 10
# --------------------------------------------------
#
# 🖼️  单币种 (single) 图片展示:
# ----------------------------------------
# ✅ 已显示 4 个图片
# ----------------------------------------

# %%
from tabulate import tabulate

def display_factor_evaluation(result):
    # 1. 基础统计指标
    basic_metrics = [
        ["信息系数(IC)", result['correlation_analysis']['IC']],
        ["秩相关系数(Rank IC)", result['correlation_analysis']['Rank_IC']],
        ["信息比率(IR)", result['information_ratio']['IR']],
        ["分组数量", result['information_ratio']['n_groups']],
        ["数据点数", f"{result['factor_return_scatter']['data_points']:,}"],
        ["异常值(>3σ)", f"{result['factor_distribution']['outlier_analysis']['>3std']*100:.2f}%"],
        ["异常值(>5σ)", f"{result['factor_distribution']['outlier_analysis']['>5std']*100:.2f}%"]
    ]
    
    # 2. 分组分析
    group_stats = result['group_analysis']['group_stats']
    group_table = []
    for idx, row in group_stats.iterrows():
        group_table.append([
            idx,
            f"{row['val_min']:.4f}",
            f"{row['val_max']:.4f}",
            f"{row['val_mean']:.4f}",
            f"{row['return_mean']:.6f}",
            f"{row['return_std']:.4f}",
            row['count']
        ])
    
    # 3. 因子分布描述
    dist_stats = result['factor_distribution']['descriptive_stats']
    distribution_metrics = [
        ["均值", f"{dist_stats['mean']:.4f}"],
        ["标准差", f"{dist_stats['std']:.4f}"],
        ["最小值", f"{dist_stats['min']:.4f}"],
        ["1%分位数", f"{dist_stats['1%']:.4f}"],
        ["5%分位数", f"{dist_stats['5%']:.4f}"],
        ["25%分位数", f"{dist_stats['25%']:.4f}"],
        ["中位数", f"{dist_stats['50%']:.4f}"],
        ["75%分位数", f"{dist_stats['75%']:.4f}"],
        ["95%分位数", f"{dist_stats['95%']:.4f}"],
        ["99%分位数", f"{dist_stats['99%']:.4f}"],
        ["最大值", f"{dist_stats['max']:.4f}"]
    ]
    
    # 4. 分组相关性
    group_correlations = []
    for i, corr in enumerate(result['information_ratio']['group_correlations']):
        group_correlations.append([f"组 {i+1}", f"{corr:.6f}"])
    
    # 5. 滚动IC分析 - 完整展示
    rolling_ic = result['rolling_ic_analysis']['rolling_ic']
    rolling_rank_ic = result['rolling_ic_analysis']['rolling_rank_ic']
    window_centers = result['rolling_ic_analysis']['window_centers']
    cumsum_ic = result['rolling_ic_analysis']['cumsum_ic']
    cumsum_rank_ic = result['rolling_ic_analysis']['cumsum_rank_ic']
    
    # 创建滚动IC数据表格
    rolling_table = []
    for i in range(len(rolling_ic)):
        rolling_table.append([
            window_centers[i].strftime('%Y-%m-%d %H:%M:%S'),
            f"{rolling_ic[i]:.6f}",
            f"{rolling_rank_ic[i]:.6f}",
            f"{cumsum_ic[i]:.6f}",
            f"{cumsum_rank_ic[i]:.6f}"
        ])
    
    # 滚动IC汇总统计
    rolling_metrics = [
        ["滚动IC均值", f"{pd.Series(rolling_ic).mean():.6f}"],
        ["滚动IC标准差", f"{pd.Series(rolling_ic).std():.6f}"],
        ["滚动Rank IC均值", f"{pd.Series(rolling_rank_ic).mean():.6f}"],
        ["滚动Rank IC标准差", f"{pd.Series(rolling_rank_ic).std():.6f}"],
        ["累积IC终值", f"{cumsum_ic[-1]:.6f}"],
        ["累积Rank IC终值", f"{cumsum_rank_ic[-1]:.6f}"],
        ["初始窗口大小", result['rolling_ic_analysis']['initial_window']],
        ["滚动步长", result['rolling_ic_analysis']['rolling_step']]
    ]
    
    # 6. 时间窗口统计
    window_stats = []
    window_data = result['factor_distribution']['window_stats'][10]
    
    # 正确处理时间窗口统计数据
    if isinstance(window_data['stats'], pd.DataFrame):
        # 如果是DataFrame结构
        for idx, row in window_data['stats'].iterrows():
            window_stats.append([
                idx,
                f"{row['mean']:.4f}",
                f"{row['std']:.4f}",
                f"{row['skew']:.4f}",
                f"{row['lambda']:.4f}",
                row['count']
            ])
    else:
        # 如果是字典结构
        for time_range, stats in window_data['stats'].items():
            window_stats.append([
                time_range,
                f"{stats['mean']:.4f}",
                f"{stats['std']:.4f}",
                f"{stats['skew']:.4f}",
                f"{stats['lambda']:.4f}",
                stats['count']
            ])
    
    # # 7. 平稳性测试结果
    # stationarity = result['stationarity_test']
    # stationarity_metrics = [
    #     ["ADF统计量", stationarity['adf_statistic']],
    #     ["P值", stationarity['p_value']],
    #     ["1%临界值", stationarity['critical_values']['1%']],
    #     ["5%临界值", stationarity['critical_values']['5%']],
    #     ["10%临界值", stationarity['critical_values']['10%']],
    #     ["是否平稳", stationarity['is_stationary']],
    #     #["显著性水平", stationarity['alpha']]
    # ]
    
    # 打印所有结果
    print("="*80)
    print("因子评估核心指标".center(80))
    print("="*80)
    print(tabulate(basic_metrics, headers=["指标", "值"], tablefmt="grid", floatfmt=".6f"))
    
    # print("\n" + "="*80)
    # print("平稳性测试结果".center(80))
    # print("="*80)
    # print(tabulate(stationarity_metrics, headers=["指标", "值"], tablefmt="grid", floatfmt=".6f"))
    
    print("\n" + "="*80)
    print("分组分析结果".center(80))
    print("="*80)
    print(tabulate(group_table, headers=["分组", "最小值", "最大值", "平均值", "收益均值", "收益标准差", "样本数"], tablefmt="grid"))
    
    print("\n" + "="*80)
    print("因子分布统计".center(80))
    print("="*80)
    print(tabulate(distribution_metrics, headers=["统计量", "值"], tablefmt="grid", floatfmt=".4f"))
    
    print("\n" + "="*80)
    print("分组相关性".center(80))
    print("="*80)
    print(tabulate(group_correlations, headers=["分组", "相关性"], tablefmt="grid", floatfmt=".6f"))
    
    print("\n" + "="*80)
    print("滚动IC分析汇总".center(80))
    print("="*80)
    print(tabulate(rolling_metrics, headers=["指标", "值"], tablefmt="grid", floatfmt=".6f"))
    
    print("\n" + "="*80)
    print("滚动IC详细数据".center(80))
    print("="*80)
    print(tabulate(rolling_table, headers=["窗口中心", "滚动IC", "滚动Rank IC", "累积IC", "累积Rank IC"], tablefmt="grid"))
    
    print("\n" + "="*80)
    print("时间窗口统计".center(80))
    print("="*80)
    print(tabulate(window_stats, headers=["时间窗口", "均值", "标准差", "偏度", "Lambda", "样本数"], tablefmt="grid"))
    print(f"时间范围: {window_data['time_ranges']}")

# 调用展示函数
display_factor_evaluation(result)
# Out:
# ================================================================================
#                                     因子评估核心指标
# ================================================================================
# +---------------------+----------------------+
# | 指标                | 值                   |
# +=====================+======================+
# | 信息系数(IC)        | 0.010508254592904985 |
# +---------------------+----------------------+
# | 秩相关系数(Rank IC) | 0.012343027107360242 |
# +---------------------+----------------------+
# | 信息比率(IR)        | 0.4862212209194522   |
# +---------------------+----------------------+
# | 分组数量            | 10                   |
# +---------------------+----------------------+
# | 数据点数            | 131,038              |
# +---------------------+----------------------+
# | 异常值(>3σ)         | 9.60%                |
# +---------------------+----------------------+
# | 异常值(>5σ)         | 0.07%                |
# +---------------------+----------------------+
#
# ================================================================================
#                                      分组分析结果
# ================================================================================
# +--------+----------+----------+----------+------------+--------------+----------+
# |   分组 |   最小值 |   最大值 |   平均值 |   收益均值 |   收益标准差 |   样本数 |
# +========+==========+==========+==========+============+==============+==========+
# |      0 |  -0.1429 |   0.0168 |  -0.0297 |  -0.000127 |       0.0148 |     6624 |
# +--------+----------+----------+----------+------------+--------------+----------+
# |      1 |   0.0171 |   0.0457 |   0.0335 |  -5.1e-05  |       0.0152 |     6528 |
# +--------+----------+----------+----------+------------+--------------+----------+
# |      2 |   0.046  |   0.0719 |   0.0593 |  -0.00132  |       0.0259 |     6528 |
# +--------+----------+----------+----------+------------+--------------+----------+
# |      3 |   0.0729 |   0.093  |   0.0835 |   0.000524 |       0.0212 |     6528 |
# +--------+----------+----------+----------+------------+--------------+----------+
# |      4 |   0.093  |   0.1099 |   0.1015 |  -0.000445 |       0.0161 |     6624 |
# +--------+----------+----------+----------+------------+--------------+----------+
# |      5 |   0.11   |   0.1247 |   0.1175 |   0.000964 |       0.0168 |     6528 |
# +--------+----------+----------+----------+------------+--------------+----------+
# |      6 |   0.1252 |   0.1409 |   0.1319 |  -0.000113 |       0.0171 |     6528 |
# +--------+----------+----------+----------+------------+--------------+----------+
# |      7 |   0.1409 |   0.1551 |   0.1478 |  -0.000319 |       0.0175 |     6528 |
# +--------+----------+----------+----------+------------+--------------+----------+
# |      8 |   0.1552 |   0.1713 |   0.1638 |   0.000942 |       0.0166 |     6624 |
# +--------+----------+----------+----------+------------+--------------+----------+
# |      9 |   0.1713 |   0.1848 |   0.1777 |   0.000791 |       0.016  |     6624 |
# +--------+----------+----------+----------+------------+--------------+----------+
# |     10 |   0.1851 |   0.2027 |   0.1936 |   0.000756 |       0.0161 |     6432 |
# +--------+----------+----------+----------+------------+--------------+----------+
# |     11 |   0.2029 |   0.2157 |   0.2102 |   0.000167 |       0.0152 |     6528 |
# +--------+----------+----------+----------+------------+--------------+----------+
# |     12 |   0.2159 |   0.2291 |   0.2226 |  -0.000664 |       0.016  |     6624 |
# +--------+----------+----------+----------+------------+--------------+----------+
# |     13 |   0.2292 |   0.2465 |   0.2385 |   0.000781 |       0.0162 |     6528 |
# +--------+----------+----------+----------+------------+--------------+----------+
# |     14 |   0.2468 |   0.264  |   0.2559 |  -0.000452 |       0.0165 |     6528 |
# +--------+----------+----------+----------+------------+--------------+----------+
# |     15 |   0.2642 |   0.2813 |   0.2725 |   0.000608 |       0.0186 |     6528 |
# +--------+----------+----------+----------+------------+--------------+----------+
# |     16 |   0.2814 |   0.2978 |   0.2892 |   0.000219 |       0.0168 |     6624 |
# +--------+----------+----------+----------+------------+--------------+----------+
# |     17 |   0.2978 |   0.3218 |   0.3093 |   9.1e-05  |       0.0208 |     6528 |
# +--------+----------+----------+----------+------------+--------------+----------+
# |     18 |   0.3221 |   0.3645 |   0.3406 |   0.00014  |       0.0219 |     6528 |
# +--------+----------+----------+----------+------------+--------------+----------+
# |     19 |   0.3646 |   0.5473 |   0.408  |   0.000676 |       0.0179 |     6526 |
# +--------+----------+----------+----------+------------+--------------+----------+
#
# ================================================================================
#                                      因子分布统计
# ================================================================================
# +-----------+---------+
# | 统计量    |      值 |
# +===========+=========+
# | 均值      |  0.1862 |
# +-----------+---------+
# | 标准差    |  0.1078 |
# +-----------+---------+
# | 最小值    | -0.1429 |
# +-----------+---------+
# | 1%分位数  | -0.0656 |
# +-----------+---------+
# | 5%分位数  |  0.0168 |
# +-----------+---------+
# | 25%分位数 |  0.1099 |
# +-----------+---------+
# | 中位数    |  0.1848 |
# +-----------+---------+
# | 75%分位数 |  0.2640 |
# +-----------+---------+
# | 95%分位数 |  0.3645 |
# +-----------+---------+
# | 99%分位数 |  0.4302 |
# +-----------+---------+
# | 最大值    |  0.5473 |
# +-----------+---------+
#
# ================================================================================
#                                      分组相关性
# ================================================================================
# +--------+-----------+
# | 分组   |    相关性 |
# +========+===========+
# | 组 1   |  0.018229 |
# +--------+-----------+
# | 组 2   |  0.012003 |
# +--------+-----------+
# | 组 3   |  0.052554 |
# +--------+-----------+
# | 组 4   | -0.009894 |
# +--------+-----------+
# | 组 5   | -0.036227 |
# +--------+-----------+
# | 组 6   | -0.011872 |
# +--------+-----------+
# | 组 7   |  0.038756 |
# +--------+-----------+
# | 组 8   |  0.021493 |
# +--------+-----------+
# | 组 9   |  0.004388 |
# +--------+-----------+
# | 组 10  |  0.033368 |
# +--------+-----------+
#
# ================================================================================
#                                     滚动IC分析汇总
# ================================================================================
# +-------------------+--------------+
# | 指标              |           值 |
# +===================+==============+
# | 滚动IC均值        |     0.013127 |
# +-------------------+--------------+
# | 滚动IC标准差      |     0.020655 |
# +-------------------+--------------+
# | 滚动Rank IC均值   |     0.015239 |
# +-------------------+--------------+
# | 滚动Rank IC标准差 |     0.020783 |
# +-------------------+--------------+
# | 累积IC终值        |     0.735097 |
# +-------------------+--------------+
# | 累积Rank IC终值   |     0.853379 |
# +-------------------+--------------+
# | 初始窗口大小      | 20000.000000 |
# +-------------------+--------------+
# | 滚动步长          |  2000.000000 |
# +-------------------+--------------+
#
# ================================================================================
#                                     滚动IC详细数据
# ================================================================================
# +---------------------+-----------+---------------+----------+---------------+
# | 窗口中心            |    滚动IC |   滚动Rank IC |   累积IC |   累积Rank IC |
# +=====================+===========+===============+==========+===============+
# | 2022-01-13 04:00:00 |  0.019416 |      0.020367 | 0.019416 |      0.020367 |
# +---------------------+-----------+---------------+----------+---------------+
# | 2022-02-03 00:00:00 |  0.006104 |      0.012655 | 0.02552  |      0.033022 |
# +---------------------+-----------+---------------+----------+---------------+
# | 2022-02-23 20:00:00 |  0.010317 |      0.015986 | 0.035837 |      0.049008 |
# +---------------------+-----------+---------------+----------+---------------+
# | 2022-03-16 16:00:00 |  0.011244 |      0.00342  | 0.04708  |      0.052428 |
# +---------------------+-----------+---------------+----------+---------------+
# | 2022-04-06 12:00:00 |  0.024134 |      0.01587  | 0.071215 |      0.068298 |
# +---------------------+-----------+---------------+----------+---------------+
# | 2022-04-27 08:00:00 |  0.02534  |      0.016085 | 0.096555 |      0.084383 |
# +---------------------+-----------+---------------+----------+---------------+
# | 2022-05-18 04:00:00 |  0.012295 |      0.003335 | 0.10885  |      0.087718 |
# +---------------------+-----------+---------------+----------+---------------+
# | 2022-06-08 00:00:00 |  0.016222 |      0.01126  | 0.125072 |      0.098977 |
# +---------------------+-----------+---------------+----------+---------------+
# | 2022-06-28 20:00:00 |  0.018815 |      0.012054 | 0.143887 |      0.111031 |
# +---------------------+-----------+---------------+----------+---------------+
# | 2022-07-19 16:00:00 |  0.012863 |      0.003252 | 0.15675  |      0.114283 |
# +---------------------+-----------+---------------+----------+---------------+
# | 2022-08-09 12:00:00 |  0.026817 |      0.017389 | 0.183567 |      0.131672 |
# +---------------------+-----------+---------------+----------+---------------+
# | 2022-08-30 08:00:00 |  0.034897 |      0.023486 | 0.218464 |      0.155158 |
# +---------------------+-----------+---------------+----------+---------------+
# | 2022-09-20 04:00:00 |  0.037257 |      0.028668 | 0.25572  |      0.183826 |
# +---------------------+-----------+---------------+----------+---------------+
# | 2022-10-11 00:00:00 |  0.02638  |      0.033876 | 0.282101 |      0.217702 |
# +---------------------+-----------+---------------+----------+---------------+
# | 2022-10-31 20:00:00 |  0.008765 |      0.020821 | 0.290866 |      0.238522 |
# +---------------------+-----------+---------------+----------+---------------+
# | 2022-11-21 16:00:00 |  0.01917  |      0.034688 | 0.310036 |      0.27321  |
# +---------------------+-----------+---------------+----------+---------------+
# | 2022-12-12 12:00:00 |  0.02909  |      0.047972 | 0.339126 |      0.321183 |
# +---------------------+-----------+---------------+----------+---------------+
# | 2023-01-02 08:00:00 |  0.027668 |      0.04159  | 0.366794 |      0.362772 |
# +---------------------+-----------+---------------+----------+---------------+
# | 2023-01-23 04:00:00 |  0.0243   |      0.043183 | 0.391094 |      0.405955 |
# +---------------------+-----------+---------------+----------+---------------+
# | 2023-02-13 00:00:00 |  0.021499 |      0.039832 | 0.412593 |      0.445787 |
# +---------------------+-----------+---------------+----------+---------------+
# | 2023-03-05 20:00:00 | -4.5e-05  |      0.030401 | 0.412548 |      0.476188 |
# +---------------------+-----------+---------------+----------+---------------+
# | 2023-03-26 16:00:00 | -0.004911 |      0.033368 | 0.407637 |      0.509556 |
# +---------------------+-----------+---------------+----------+---------------+
# | 2023-04-16 12:00:00 | -0.018189 |      0.024696 | 0.389448 |      0.534253 |
# +---------------------+-----------+---------------+----------+---------------+
# | 2023-05-07 08:00:00 |  0.007642 |      0.034663 | 0.39709  |      0.568916 |
# +---------------------+-----------+---------------+----------+---------------+
# | 2023-05-28 04:00:00 |  0.018056 |      0.046714 | 0.415146 |      0.61563  |
# +---------------------+-----------+---------------+----------+---------------+
# | 2023-06-18 00:00:00 |  0.00573  |      0.034446 | 0.420877 |      0.650076 |
# +---------------------+-----------+---------------+----------+---------------+
# | 2023-07-08 20:00:00 | -0.006881 |      0.020416 | 0.413995 |      0.670492 |
# +---------------------+-----------+---------------+----------+---------------+
# | 2023-07-29 16:00:00 |  0.039453 |      0.044648 | 0.453448 |      0.715139 |
# +---------------------+-----------+---------------+----------+---------------+
# | 2023-08-19 12:00:00 |  0.046178 |      0.041706 | 0.499626 |      0.756846 |
# +---------------------+-----------+---------------+----------+---------------+
# | 2023-09-09 08:00:00 |  0.028971 |      0.022312 | 0.528597 |      0.779158 |
# +---------------------+-----------+---------------+----------+---------------+
# | 2023-09-30 04:00:00 |  0.042302 |      0.019623 | 0.5709   |      0.798781 |
# +---------------------+-----------+---------------+----------+---------------+
# | 2023-10-21 00:00:00 |  0.039535 |      0.016073 | 0.610435 |      0.814854 |
# +---------------------+-----------+---------------+----------+---------------+
# | 2023-11-10 20:00:00 |  0.037503 |      0.017809 | 0.647938 |      0.832663 |
# +---------------------+-----------+---------------+----------+---------------+
# | 2023-12-01 16:00:00 |  0.033553 |      0.016901 | 0.681491 |      0.849565 |
# +---------------------+-----------+---------------+----------+---------------+
# | 2023-12-22 12:00:00 |  0.027157 |      0.006393 | 0.708648 |      0.855957 |
# +---------------------+-----------+---------------+----------+---------------+
# | 2024-01-12 08:00:00 |  0.032592 |      0.014013 | 0.741239 |      0.86997  |
# +---------------------+-----------+---------------+----------+---------------+
# | 2024-02-02 04:00:00 |  0.035456 |      0.021248 | 0.776695 |      0.891218 |
# +---------------------+-----------+---------------+----------+---------------+
# | 2024-02-23 00:00:00 |  0.01763  |      0.004594 | 0.794326 |      0.895812 |
# +---------------------+-----------+---------------+----------+---------------+
# | 2024-03-14 20:00:00 |  0.020724 |      0.01909  | 0.815049 |      0.914902 |
# +---------------------+-----------+---------------+----------+---------------+
# | 2024-04-04 16:00:00 |  0.0246   |      0.023984 | 0.839649 |      0.938886 |
# +---------------------+-----------+---------------+----------+---------------+
# | 2024-04-25 12:00:00 |  0.025367 |      0.032335 | 0.865016 |      0.971221 |
# +---------------------+-----------+---------------+----------+---------------+
# | 2024-05-16 08:00:00 |  0.018926 |      0.0229   | 0.883942 |      0.994121 |
# +---------------------+-----------+---------------+----------+---------------+
# | 2024-06-06 04:00:00 |  0.020775 |      0.02278  | 0.904717 |      1.0169   |
# +---------------------+-----------+---------------+----------+---------------+
# | 2024-06-27 00:00:00 |  0.014428 |      0.018484 | 0.919145 |      1.03538  |
# +---------------------+-----------+---------------+----------+---------------+
# | 2024-07-17 20:00:00 |  0.008843 |      0.013301 | 0.927987 |      1.04869  |
# +---------------------+-----------+---------------+----------+---------------+
# | 2024-08-07 16:00:00 |  0.016263 |      0.01631  | 0.94425  |      1.06499  |
# +---------------------+-----------+---------------+----------+---------------+
# | 2024-08-28 12:00:00 |  0.002088 |     -0.005707 | 0.946339 |      1.05929  |
# +---------------------+-----------+---------------+----------+---------------+
# | 2024-09-18 08:00:00 | -0.01236  |     -0.009734 | 0.933978 |      1.04955  |
# +---------------------+-----------+---------------+----------+---------------+
# | 2024-10-09 04:00:00 | -0.015977 |     -0.018795 | 0.918001 |      1.03076  |
# +---------------------+-----------+---------------+----------+---------------+
# | 2024-10-30 00:00:00 | -0.017734 |     -0.02117  | 0.900267 |      1.00959  |
# +---------------------+-----------+---------------+----------+---------------+
# | 2024-11-19 20:00:00 | -0.027928 |     -0.034387 | 0.872339 |      0.975201 |
# +---------------------+-----------+---------------+----------+---------------+
# | 2024-12-10 16:00:00 | -0.021452 |     -0.021988 | 0.850887 |      0.953214 |
# +---------------------+-----------+---------------+----------+---------------+
# | 2024-12-31 12:00:00 | -0.030577 |     -0.03269  | 0.82031  |      0.920524 |
# +---------------------+-----------+---------------+----------+---------------+
# | 2025-01-21 08:00:00 | -0.037394 |     -0.03503  | 0.782916 |      0.885493 |
# +---------------------+-----------+---------------+----------+---------------+
# | 2025-02-11 04:00:00 | -0.0315   |     -0.02417  | 0.751416 |      0.861323 |
# +---------------------+-----------+---------------+----------+---------------+
# | 2025-03-04 00:00:00 | -0.016319 |     -0.007945 | 0.735097 |      0.853379 |
# +---------------------+-----------+---------------+----------+---------------+
#
# ================================================================================
#                                      时间窗口统计
# ================================================================================
# +--------------------------------------------+--------+----------+---------+----------+----------+
# | 时间窗口                                   |   均值 |   标准差 |    偏度 |   Lambda |   样本数 |
# +============================================+========+==========+=========+==========+==========+
# | [2021-10-01, 2022-02-14 11:55:30)          | 0.1448 |   0.1081 |  0.0531 |  -0.6563 |    13104 |
# +--------------------------------------------+--------+----------+---------+----------+----------+
# | [2022-02-14 11:55:30, 2022-06-30 23:51:00) | 0.1847 |   0.1211 | -0.3536 |  -0.9342 |    13104 |
# +--------------------------------------------+--------+----------+---------+----------+----------+
# | [2022-06-30 23:51:00, 2022-11-14 11:46:30) | 0.1926 |   0.0629 | -0.1497 |  -0.2922 |    13104 |
# +--------------------------------------------+--------+----------+---------+----------+----------+
# | [2022-11-14 11:46:30, 2023-03-30 23:42:00) | 0.1698 |   0.095  |  0.344  |  -0.73   |    13103 |
# +--------------------------------------------+--------+----------+---------+----------+----------+
# | [2023-03-30 23:42:00, 2023-08-14 11:37:30) | 0.2104 |   0.0787 | -0.2645 |  -0.8532 |    13104 |
# +--------------------------------------------+--------+----------+---------+----------+----------+
# | [2023-08-14 11:37:30, 2023-12-28 23:33:00) | 0.1741 |   0.1154 |  1.0206 |   0.2474 |    13104 |
# +--------------------------------------------+--------+----------+---------+----------+----------+
# | [2023-12-28 23:33:00, 2024-05-13 11:28:30) | 0.1708 |   0.1342 | -0.1384 |  -0.62   |    13103 |
# +--------------------------------------------+--------+----------+---------+----------+----------+
# | [2024-05-13 11:28:30, 2024-09-26 23:24:00) | 0.1278 |   0.0826 | -0.1313 |  -0.7948 |    13104 |
# +--------------------------------------------+--------+----------+---------+----------+----------+
# | [2024-09-26 23:24:00, 2025-02-10 11:19:30) | 0.2435 |   0.1199 |  0.0751 |  -0.7349 |    13104 |
# +--------------------------------------------+--------+----------+---------+----------+----------+
# | [2025-02-10 11:19:30, 2025-06-26 23:15:00) | 0.2435 |   0.0727 | -0.1833 |  -1.0204 |    13103 |
# +--------------------------------------------+--------+----------+---------+----------+----------+
# 时间范围: ['2021-10-01 ~ 2022-02-14', '2022-02-14 ~ 2022-06-30', '2022-06-30 ~ 2022-11-14', '2022-11-14 ~ 2023-03-30', '2023-03-30 ~ 2023-08-14', '2023-08-14 ~ 2023-12-28', '2023-12-28 ~ 2024-05-13', '2024-05-13 ~ 2024-09-26', '2024-09-26 ~ 2025-02-10', '2025-02-10 ~ 2025-06-26']
