# %%
import json
import os

# %%
# --- 配置 ---
# 您要查看的Jupyter Notebook文件的完整路径
NOTEBOOK_FILE_PATH = "/public/src/4L_lecture0.ipynb"

# %%
# --- 主程序 ---
def display_notebook_content(file_path):
    """
    解析并以可读格式打印Jupyter Notebook文件的内容。
    """
    print(f"--- 准备显示文件: {os.path.basename(file_path)} ---")

    # 1. 检查文件是否存在
    if not os.path.exists(file_path):
        print(f"\n[错误] 文件不存在，请检查路径是否正确: {file_path}")
        return

    # 2. 读取并解析JSON文件
    try:
        with open(file_path, 'r', encoding='utf-8') as f:
            data = json.load(f)
    except Exception as e:
        print(f"\n[错误] 读取或解析文件时出错: {e}")
        print("请确认这是一个有效的Jupyter Notebook文件。")
        return

    # 3. 检查文件基本结构
    if 'cells' not in data or not isinstance(data['cells'], list):
        print("\n[错误] 文件格式不正确，找不到核心的'cells'内容。")
        return

    print("=" * 60)

    # 4. 遍历所有单元格并打印
    for i, cell in enumerate(data['cells']):
        cell_type = cell.get('cell_type', 'unknown')
        source_lines = cell.get('source', [])
        content = "".join(source_lines)

        # 打印一个清晰的单元格分隔符和标题
        print(f"\n▌ 单元格 #{i + 1}  [类型: {cell_type.capitalize()}]")
        print("-" * 30)
        
        # 打印单元格的实际内容
        print(content)

    print("\n" + "=" * 60)
    print(f"--- 文件内容显示完毕: {os.path.basename(file_path)} ---")

# %%
if __name__ == "__main__":
    display_notebook_content(NOTEBOOK_FILE_PATH)
# Out:
# --- 准备显示文件: 4L_lecture0.ipynb ---
# ============================================================
#
# ▌ 单元格 #1  [类型: Markdown]
# ------------------------------
# # 初始化
#
# ▌ 单元格 #2  [类型: Code]
# ------------------------------
# import os
# import sys
# import logging
# import warnings
# import pickle
# import pandas as  pd
# import yaml
# import time
# import argparse
# from datetime import datetime
# from pathlib import Path
# from typing import Dict, Any, Callable, Optional, List, Tuple
#
# ▌ 单元格 #3  [类型: Markdown]
# ------------------------------
# ## 图灵机的原理
#
# ▌ 单元格 #4  [类型: Markdown]
# ------------------------------
# ## 实现一个brainfuck语言
#
# ▌ 单元格 #5  [类型: Code]
# ------------------------------
# from IPython.display import display, Markdown, HTML, clear_output
# import time
#
# class BrainfuckInterpreter:
#     def __init__(self, mem_size=30000):
#         self.memory = [0] * mem_size
#         self.pointer = 0
#         self.mem_size = mem_size
#
#         self.program = ""
#         self.pc = 0
#         self.output = []
#         self.input_buffer = []
#         self.input_index = 0
#
#         self.steps = 0
#         self.max_steps = 2000000 # 增加到 200 万步
#         self.running = False
#
#         self.bracket_map = {}
#
#     def load_program(self, program, input_str=""):
#         valid_chars = {'>', '<', '+', '-', '.', ',', '[', ']'}
#         self.program = ''.join(c for c in program if c in valid_chars)
#         self.input_buffer = list(input_str)
#         self.input_index = 0
#
#         self.pc = 0
#         self.pointer = 0
#         self.output = []
#         self.steps = 0
#         self.running = True
#
#         self._precompute_brackets()
#
#     def _precompute_brackets(self):
#         stack = []
#         self.bracket_map = {}
#
#         for idx, cmd in enumerate(self.program):
#             if cmd == '[':
#                 stack.append(idx)
#             elif cmd == ']':
#                 if stack:
#                     start = stack.pop()
#                     self.bracket_map[start] = idx
#                     self.bracket_map[idx] = start
#                 else:
#                     raise SyntaxError(f"在位置 {idx} 处发现未匹配的 ']'")
#
#         if stack:
#             raise SyntaxError(f"在位置 {stack[-1]} 处发现未匹配的 '['")
#
#     def step(self):
#         if not self.running or self.pc >= len(self.program) or self.steps >= self.max_steps:
#             self.running = False
#             return False
#
#         cmd = self.program[self.pc]
#         self.steps += 1
#
#         if cmd == '>':
#             self.pointer = (self.pointer + 1) % self.mem_size
#             self.pc += 1
#         elif cmd == '<':
#             self.pointer = (self.pointer - 1) % self.mem_size
#             self.pc += 1
#         elif cmd == '+':
#             self.memory[self.pointer] = (self.memory[self.pointer] + 1) % 256
#             self.pc += 1
#         elif cmd == '-':
#             self.memory[self.pointer] = (self.memory[self.pointer] - 1) % 256
#             self.pc += 1
#         elif cmd == '.':
#             char = chr(self.memory[self.pointer])
#             self.output.append(char)
#             self.pc += 1
#         elif cmd == ',':
#             if self.input_index < len(self.input_buffer):
#                 self.memory[self.pointer] = ord(self.input_buffer[self.input_index])
#                 self.input_index += 1
#             else:
#                 self.memory[self.pointer] = 0
#             self.pc += 1
#         elif cmd == '[':
#             if self.memory[self.pointer] == 0:
#                 self.pc = self.bracket_map[self.pc] + 1
#             else:
#                 self.pc += 1
#         elif cmd == ']':
#             if self.memory[self.pointer] != 0:
#                 self.pc = self.bracket_map[self.pc]
#             else:
#                 self.pc += 1
#
#         return True
#
#     def run(self, max_steps=None):
#         if max_steps is None:
#             max_steps = self.max_steps
#
#         initial_steps = self.steps
#         while self.running and self.steps < initial_steps + max_steps:
#             if not self.step():
#                 break
#
#         return ''.join(self.output)
#
#     def visualize(self, width=30):
#         # 计算内存显示范围
#         start_mem = max(0, self.pointer - width // 2)
#         end_mem = min(self.mem_size, start_mem + width)
#
#         mem_display_parts = []
#         for i in range(start_mem, end_mem):
#             value = self.memory[i]
#             if i == self.pointer:
#                 # Use span for highlighting with HTML directly
#                 mem_display_parts.append(f"<span style='background-color: #add8e6; font-weight: bold;'> {value:3d} </span>") # Light blue background for current cell
#             else:
#                 mem_display_parts.append(f" {value:3d} ")
#
#         # We'll build a string that looks like code, but isn't in Markdown backticks for memory
#         mem_line = ''.join(mem_display_parts)
#
#         # 构建指令可视化
#         code_view_start = max(0, self.pc - 15)
#         code_view_end = min(len(self.program), self.pc + 15)
#
#         code_display_parts = []
#         for i in range(code_view_start, code_view_end):
#             if i == self.pc:
#                 # Use span for highlighting with HTML directly
#                 code_display_parts.append(f"<span style='background-color: yellow; font-weight: bold;'>{self.program[i]}</span>")
#             else:
#                 code_display_parts.append(self.program[i])
#
#         # Use <pre> tag for preformatted text (like code) within HTML
#         # This preserves whitespace and doesn't wrap lines by default
#         code_line_html = f"<pre>{''.join(code_display_parts)}</pre>"
#
#         # Use <pre> for memory as well to preserve formatting
#         mem_line_html = f"<pre>{mem_line}</pre>"
#
#         # Display state using Markdown for titles, and HTML for the preformatted blocks
#         display(Markdown(f"""
# ---
# ### **解释器状态** (步数: {self.steps}, 指针: {self.pointer}, PC: {self.pc})
# **内存视图**:
# """))
#         display(HTML(mem_line_html)) # Display memory as HTML
#         display(Markdown(f"""
# **当前指令**:
# """))
#         display(HTML(code_line_html)) # Display code as HTML
#         display(Markdown(f"""
# **输出**:
# `{''.join(self.output)}`
# ---
# """))
#
# # --- 测试程序 ---
# hello_world = """
# ++++++++[>++++[>++>+++>+++>+<<<<-]>+>+>->>+[<]<-]>>.>---.+++++++..+++.>>.<-.<.+++.------.-------.>>+.>++.
# """
#
# # 创建解释器实例，设置合适的内存大小
# interpreter = BrainfuckInterpreter(mem_size=100)
#
# # --- 单步执行演示 ---
# display(Markdown("## **Brainfuck 解释器演示：单步执行**"))
# display(Markdown("*(正在显示前 500 步的实时可视化)*"))
#
# interpreter.load_program(hello_world)
#
# for _ in range(500):
#     if not interpreter.step():
#         break
#     interpreter.visualize(width=20)
#     time.sleep(0.1)
#     clear_output(wait=True)
#
# display(Markdown("### **单步动画演示结束。**"))
# display(Markdown("*(现在正在运行程序的其余部分直到完成...)*"))
#
# # --- 完整程序执行 ---
# interpreter.run()
#
# # --- 最终结果 ---
# clear_output(wait=True)
# display(Markdown("## **Brainfuck 解释器演示：最终结果**"))
# interpreter.visualize(width=20)
# display(Markdown(f"**完整程序输出**: `{''.join(interpreter.output)}`"))
#
# ▌ 单元格 #6  [类型: Code]
# ------------------------------
# import sys
# import pandas as pd
# import numpy as np
# sys.path.append('/public/src')
# from factor_evaluation_server import FactorEvaluation
# evaluator=FactorEvaluation(time_periods=['1h'],future_return_periods=10)
#
# ▌ 单元格 #7  [类型: Code]
# ------------------------------
# def sieve_of_eratosthenes(limit):
#     """
#     使用埃拉托斯特尼筛法找出小于或等于给定 limit 的所有素数。
#
#     参数:
#         limit (int): 查找素数的上限。
#
#     返回:
#         list: 一个包含所有素数的列表。
#     """
#     if limit < 2:
#         return []
#
#     primes = [True] * (limit + 1)
#     primes[0] = primes[1] = False # 0 和 1 不是素数
#
#     p = 2
#     while p * p <= limit:
#         if primes[p]:
#
#             for multiple in range(p * p, limit + 1, p):
#                 primes[multiple] = False
#         p += 1
#     prime_numbers = []
#     for num in range(2, limit + 1):
#         if primes[num]:
#             prime_numbers.append(num)
#
#     return prime_numbers
#
# # 找出 100 以内的所有素数
# limit = 100
#
#
#
# ▌ 单元格 #8  [类型: Markdown]
# ------------------------------
# ## 装饰器和列表生成器
#
# ▌ 单元格 #9  [类型: Code]
# ------------------------------
# def gen_cross_ma_func(f1:str,f2:str,p1:int,p2:int,agg1:callable,agg2):
#     def func(d:pd.Series):
#         return (d[f1].rolling(p1).agg(agg1))/(d[f2].rolling(p2).agg(agg2))
#
#     return func
#
# ▌ 单元格 #10  [类型: Code]
# ------------------------------
# fields = ['open','high','close','low']
# primes = sieve_of_eratosthenes(limit)
# aggs = [('mean',lambda x:x.mean()),('std',lambda x:x.std()),('max',lambda x:x.max()),('min',lambda x:x.min())]
#
# ▌ 单元格 #11  [类型: Code]
# ------------------------------
# cross_mas = [
#     (f'cross_ma_{f1}_{p1}_{agg1[0]}_{f2}_{p2}_{agg2[0]}',gen_cross_ma_func(f1, f2, p1, p2, agg1[1],agg2[1]))
#     for i, f1 in enumerate(fields)
#     for f2 in fields[i+1:]
#     for j, p1 in enumerate(primes)
#     for p2 in primes[j+1:]
#     for agg1 in aggs
#     for agg2 in aggs
# ]
#
# ▌ 单元格 #12  [类型: Code]
# ------------------------------
# len(cross_mas)
#
# ▌ 单元格 #13  [类型: Code]
# ------------------------------
# cnt = 0
# for name,func in cross_mas:
#     cnt = cnt+1
#     evaluator.set_factor(
#         factor_func = func,
#         factor_name=name,
#     )
#     if cnt>5:
#         break
#
# ▌ 单元格 #14  [类型: Code]
# ------------------------------
# import gc # 导入垃圾回收模块
#
# class Node:
#     def __init__(self, name):
#         self.name = name
#         self.next = None # 指向下一个节点的引用
#         self.data = np.random.randn(1000,10000,10)
#
#     def set_next(self, node):
#         self.next = node
#
#     def __del__(self):
#         """当对象被回收时，这个方法会被调用"""
#         print(f"Node '{self.name}' 已被回收。")
#
# print("--- 循环引用示例 ---")
#
# # 禁用自动垃圾回收，以便我们手动触发
# gc.disable()
#
# # 创建两个相互引用的对象
# node1 = Node("Node1")
# node2 = Node("Node2")
#
# node1.set_next(node2) # Node1 引用 Node2
# node2.set_next(node1) # Node2 引用 Node1 (形成循环)
#
# # 此时，node1 和 node2 的引用计数都为 2 (各自被外部变量和对方引用)
# print(f"node1 的引用计数 (外部 + 循环): {sys.getrefcount(node1) - 1}")
# print(f"node2 的引用计数 (外部 + 循环): {sys.getrefcount(node2) - 1}")
#
# # 删除外部引用
# del node1
# del node2
# print("\n已删除外部引用 node1 和 node2。")
#
# # 此时，我们无法从外部访问 Node1 和 Node2，但它们相互引用，引用计数不为 0
# # 所以 __del__ 方法不会被调用 (表明它们未被回收)
#
# print("尝试手动触发垃圾回收...")
# # 手动触发分代垃圾回收
# collected_count = gc.collect()
# print(f"垃圾回收器回收了 {collected_count} 个对象。")
#
# # 重新启用自动垃圾回收
# gc.enable()
# print("\n垃圾回收已重新启用。")
#
# ▌ 单元格 #15  [类型: Code]
# ------------------------------
#
#
# ============================================================
# --- 文件内容显示完毕: 4L_lecture0.ipynb ---
